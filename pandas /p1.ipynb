# %%
import pandas as pd
df=pd.read_csv("/Users/inamkhan/Desktop/MAIN/Machine Learning/Exam ml/student1.csv")
df.head()
# Out:
#    Student_ID  Gender  Age   Department  Attendance_%  Study_Hours_per_Week  \
# 0           1    Male   20           CS         59.91                    30
# 1           2  Female   24  Mathematics         50.46                    31
# 2           3    Male   24     Business         81.36                    44
# 3           4    Male   24  Mathematics         65.82                    28
# 4           5    Male   21  Engineering         98.66                    12
#
#    Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  \
# 0          80.01        50.94            91.05        90.12
# 1          80.22        75.83            69.48        74.07
# 2          94.07        81.59            59.90        91.05
# 3          40.96        68.11            79.38        91.23
# 4          91.18        45.86            91.32        65.86
#
#    Participation_Score  Projects_Score  Total_Score Grade  Backlogs  \
# 0                53.15           71.24        49.68     C         0
# ...

# %%
a=df[df["Age"]>3]
print(a.head())
# Out:
#    Student_ID  Gender  Age   Department  Attendance_%  Study_Hours_per_Week  \
# 0           1    Male   20           CS         59.91                    30
# 1           2  Female   24  Mathematics         50.46                    31
# 2           3    Male   24     Business         81.36                    44
# 3           4    Male   24  Mathematics         65.82                    28
# 4           5    Male   21  Engineering         98.66                    12
#
#    Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  \
# 0          80.01        50.94            91.05        90.12
# 1          80.22        75.83            69.48        74.07
# 2          94.07        81.59            59.90        91.05
# 3          40.96        68.11            79.38        91.23
# 4          91.18        45.86            91.32        65.86
#
#    Participation_Score  Projects_Score  Total_Score Grade  Backlogs  \
# 0                53.15           71.24        49.68     C         0
# ...

# %%
df.insert(0,"Inam",df["Total_Score"]*0.3)
df.head()
# Out:
#      Inam  Student_ID  Gender  Age   Department  Attendance_%  \
# 0  14.904           1    Male   20           CS         59.91
# 1  17.319           2  Female   24  Mathematics         50.46
# 2  15.903           3    Male   24     Business         81.36
# 3  29.556           4    Male   24  Mathematics         65.82
# 4  18.534           5    Male   21  Engineering         98.66
#
#    Study_Hours_per_Week  Midterm_Score  Final_Score  Assignments_Avg  ...  \
# 0                    30          80.01        50.94            91.05  ...
# 1                    31          80.22        75.83            69.48  ...
# 2                    44          94.07        81.59            59.90  ...
# 3                    28          40.96        68.11            79.38  ...
# 4                    12          91.18        45.86            91.32  ...
#
#    Participation_Score  Projects_Score  Total_Score  Grade Backlogs  \
# 0                53.15           71.24        49.68      C        0
# ...

# %%
df["Main"]=df["Attendance_%"]*0.4
df.head()
# Out:
#      Inam  Student_ID  Gender  Age   Department  Attendance_%  \
# 0  14.904           1    Male   20           CS         59.91
# 1  17.319           2  Female   24  Mathematics         50.46
# 2  15.903           3    Male   24     Business         81.36
# 3  29.556           4    Male   24  Mathematics         65.82
# 4  18.534           5    Male   21  Engineering         98.66
#
#    Study_Hours_per_Week  Midterm_Score  Final_Score  Assignments_Avg  ...  \
# 0                    30          80.01        50.94            91.05  ...
# 1                    31          80.22        75.83            69.48  ...
# 2                    44          94.07        81.59            59.90  ...
# 3                    28          40.96        68.11            79.38  ...
# 4                    12          91.18        45.86            91.32  ...
#
#    Projects_Score  Total_Score  Grade  Backlogs Internship  Scholarship  \
# ...

# %%
df.loc[1,"Inam"]=10000
df.head()
# Out:
#         Inam  Student_ID  Gender  Age   Department  Attendance_%  \
# 0     14.904           1    Male   20           CS         59.91
# 1  10000.000           2  Female   24  Mathematics         50.46
# 2     15.903           3    Male   24     Business         81.36
# 3     29.556           4    Male   24  Mathematics         65.82
# 4     18.534           5    Male   21  Engineering         98.66
#
#    Study_Hours_per_Week  Midterm_Score  Final_Score  Assignments_Avg  ...  \
# 0                    30          80.01        50.94            91.05  ...
# 1                    31          80.22        75.83            69.48  ...
# 2                    44          94.07        81.59            59.90  ...
# 3                    28          40.96        68.11            79.38  ...
# 4                    12          91.18        45.86            91.32  ...
#
#    Projects_Score  Total_Score  Grade  Backlogs Internship  Scholarship  \
# ...

# %%
df.loc[(df["Age"] > 30) & (df["Final_Score"] < 30), "Final_Score"] *= 2

# %%
df.loc[(df["Attendance_%"]>80) & (df["Study_Hours_per_Week"]>40),"Final_Score"]+=10
df["Final_Score"].head()
# Out:
# 0    50.94
# 1    75.83
# 2    91.59
# 3    68.11
# 4    45.86
# Name: Final_Score, dtype: float64
